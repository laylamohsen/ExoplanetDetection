# %% [markdown]
# # Importing Libraries

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics as skmetrics
from sklearn.metrics import mean_squared_error, precision_score, confusion_matrix, accuracy_score
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn.model_selection import cross_validate

# %%
ls
# Out:
# Cleaned_NasaExoplanetArchive.csv      NasaExoplanetArchive.csv
# Exoplanet-Detection.ipynb             README.md
# LOG_Cleaned_NasaExoplanetArchive.csv

# %% [markdown]
# # Data Preprocessing

# %%
df = pd.read_csv('NasaExoplanetArchive.csv')
print(df.head())
print(df.shape)
# Out:
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2      3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  ...  \
# 0      1.000              0              0              0  ...
# 1      0.969              0              0              0  ...
# 2      0.000              0              1              0  ...
# 3      0.000              0              1              0  ...
# 4      1.000              0              0              0  ...
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 50 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              9564 non-null   int64
#  1   kepid              9564 non-null   int64
#  2   kepoi_name         9564 non-null   object
#  3   kepler_name        2294 non-null   object
#  4   koi_disposition    9564 non-null   object
#  5   koi_pdisposition   9564 non-null   object
#  6   koi_score          8054 non-null   float64
#  7   koi_fpflag_nt      9564 non-null   int64
#  8   koi_fpflag_ss      9564 non-null   int64
#  9   koi_fpflag_co      9564 non-null   int64
#  10  koi_fpflag_ec      9564 non-null   int64
#  11  koi_period         9564 non-null   float64
#  12  koi_period_err1    9110 non-null   float64
#  13  koi_period_err2    9110 non-null   float64
#  14  koi_time0bk        9564 non-null   float64
#  15  koi_time0bk_err1   9110 non-null   float64
# ...

# %%
#to avoid losing data permanently when dropping columns, we will make a copy
#we will drop the kepID, KOI name & kepler name do it doesn't memorize
exoplanets = df.copy()
exoplanets.columns
# Out:
# Index(['rowid', 'kepid', 'kepoi_name', 'kepler_name', 'koi_disposition',
#        'koi_pdisposition', 'koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss',
#        'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period', 'koi_period_err1',
#        'koi_period_err2', 'koi_time0bk', 'koi_time0bk_err1',
#        'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2',
#        'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth',
#        'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1',
#        'koi_prad_err2', 'koi_teq', 'koi_teq_err1', 'koi_teq_err2', 'koi_insol',
#        'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num',
#        'koi_tce_delivname', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2',
#        'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad',
#        'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec', 'koi_kepmag'],
#       dtype='object')

# %% [markdown]
# ## I. Dropping columns

# %% [markdown]
# ### 1. Identification columns
# we will drop the kepID, KOI name & kepler name do it doesn't memorize
# & because it doesnt add value in classification features

# %%
exoplanets.drop(columns=['rowid','kepid','kepoi_name','kepler_name'], inplace=True)
exoplanets.columns
# Out:
# Index(['koi_disposition', 'koi_pdisposition', 'koi_score', 'koi_fpflag_nt',
#        'koi_fpflag_ss', 'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period',
#        'koi_period_err1', 'koi_period_err2', 'koi_time0bk', 'koi_time0bk_err1',
#        'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2',
#        'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth',
#        'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1',
#        'koi_prad_err2', 'koi_teq', 'koi_teq_err1', 'koi_teq_err2', 'koi_insol',
#        'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num',
#        'koi_tce_delivname', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2',
#        'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad',
#        'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec', 'koi_kepmag'],
#       dtype='object')

# %% [markdown]
# ***
# ### 2. Feature columns that won't benefit in detecton of exoplanets
# we will drop all the features we won't use (reasons stated in document)

# %%
exoplanets.drop(columns=['koi_disposition','koi_score','koi_fpflag_ss','koi_fpflag_co', 'koi_fpflag_ec',
                        'koi_period_err1', 'koi_period_err2', 'koi_time0bk_err1', 'koi_time0bk_err2',
                        'koi_impact', 'koi_impact_err1', 'koi_impact_err2','koi_duration_err1', 
                         'koi_duration_err2',  'koi_depth_err1', 'koi_depth_err2','koi_prad_err1',
                         'koi_prad_err2', 'koi_teq', 'koi_teq_err1', 'koi_teq_err2',  'koi_insol_err1',
                         'koi_insol_err2', 'koi_tce_plnt_num','koi_tce_delivname', 'koi_steff', 
                         'koi_steff_err1', 'koi_steff_err2', 'koi_slogg_err1', 'koi_slogg_err2',
                         'koi_srad_err1', 'koi_srad_err2','ra', 'dec', 'koi_kepmag' ], inplace=True)
exoplanets.columns
# Out:
# Index(['koi_pdisposition', 'koi_fpflag_nt', 'koi_period', 'koi_time0bk',
#        'koi_duration', 'koi_depth', 'koi_prad', 'koi_insol', 'koi_model_snr',
#        'koi_slogg', 'koi_srad'],
#       dtype='object')

# %% [markdown]
# ***
# ## II. Feature Engineering

# %% [markdown]
# ***
# ### 1. Label Encoding
#   we want to predict koi_pdisposition, which is either "CANDIDATE" (i.e exoplanet found)
#  "FALSE POSITIVE" (i.e no exoplanet found)
# -  since they are strings, we will do direct mapping where false positive is 0 and candidate is 1

# %%
class_names = exoplanets['koi_pdisposition'].unique()
class_names
# Out:
# array(['CANDIDATE', 'FALSE POSITIVE'], dtype=object)

# %%
direct_mapping = {'FALSE POSITIVE': 0, 'CANDIDATE': 1}
exoplanets['koi_pdisposition'] = df['koi_pdisposition'].map(direct_mapping)

# %%
class_names = exoplanets['koi_pdisposition'].unique()
class_names
# Out:
# array([1, 0])

# %% [markdown]
# ***
# ### 2. Replacing Unknown Values

# %% [markdown]
# checking which columns have null values

# %%
exoplanets.isna().any()
copy_exoplanets = exoplanets.copy()

# %% [markdown]
# ***
# - checking which technique for NA filling based on number of NAs
# - if number is small --> drop, if not --> interpolation using some auxiliary feature OR mean of corresponding distribution

# %%
exoplanets.isna().sum()
# Out:
# koi_pdisposition      0
# koi_fpflag_nt         0
# koi_period            0
# koi_time0bk           0
# koi_duration          0
# koi_depth           363
# koi_prad            363
# koi_insol           321
# koi_model_snr       363
# koi_slogg           363
# koi_srad            363
# dtype: int64

# %% [markdown]
# ***
# - trying to find a correlation between NAs

# %%
null = exoplanets[(exoplanets["koi_depth"].isna()) & ~(exoplanets["koi_insol"].isna())]
null
# Out:
#       koi_pdisposition  koi_fpflag_nt  koi_period  koi_time0bk  koi_duration  \
# 492                  0              1    1.634846   134.512115          6.11
# 2723                 0              1   21.341970   134.094000         10.73
# 3590                 0              1   87.140633   169.262000         18.11
# 3880                 0              1   14.589393   136.140700         15.54
# 4887                 0              0    3.471400   133.750744          1.55
# 5255                 0              0    1.103978   131.573418          0.74
# 5366                 0              0    2.389201   132.059910          3.15
# 5965                 0              1    1.395089   132.059107          2.09
# 6082                 0              1   25.221893   143.631600         14.84
# 6188                 0              1   94.818136   186.326200         83.31
# 7009                 0              0    0.876832   132.061420          1.96
# ...

# %% [markdown]
# ***
# since no clear correlation is there, we will take the mean of corresponding distribution (and we might try interpolation using some auxiliary features during testing and see which gives better results)

# %%
exoplanets.isna()
# Out:
#       koi_pdisposition  koi_fpflag_nt  koi_period  koi_time0bk  koi_duration  \
# 0                False          False       False        False         False
# 1                False          False       False        False         False
# 2                False          False       False        False         False
# 3                False          False       False        False         False
# 4                False          False       False        False         False
# ...                ...            ...         ...          ...           ...
# 9559             False          False       False        False         False
# 9560             False          False       False        False         False
# 9561             False          False       False        False         False
# 9562             False          False       False        False         False
# 9563             False          False       False        False         False
#
# ...

# %%
exoplanets.fillna(exoplanets.mean(), inplace=True)

#exoplanets.interpolate(method='linear', inplace=True) <-- second option to be tested for later

# %%
copy_exoplanets.isna().any()
# Out:
# koi_pdisposition    False
# koi_fpflag_nt       False
# koi_period          False
# koi_time0bk         False
# koi_duration        False
# koi_depth            True
# koi_prad             True
# koi_insol            True
# koi_model_snr        True
# koi_slogg            True
# koi_srad             True
# dtype: bool

# %%
copy_exoplanets.dropna(inplace=True)

# %%
copy_exoplanets.isna().any()
# Out:
# koi_pdisposition    False
# koi_fpflag_nt       False
# koi_period          False
# koi_time0bk         False
# koi_duration        False
# koi_depth           False
# koi_prad            False
# koi_insol           False
# koi_model_snr       False
# koi_slogg           False
# koi_srad            False
# dtype: bool

# %% [markdown]
# ## III. Scaling

# %% [markdown]
# ### 1. Checking distributions to determine how to scale

# %%
exoplanets.describe()
# Out:
#        koi_pdisposition  koi_fpflag_nt     koi_period  koi_time0bk  \
# count       9564.000000    9564.000000    9564.000000  9564.000000
# mean           0.470096       0.188206      75.671358   166.183251
# std            0.499131       0.390897    1334.744046    67.918960
# min            0.000000       0.000000       0.241843   120.515914
# 25%            0.000000       0.000000       2.733684   132.761718
# 50%            0.000000       0.000000       9.752831   137.224595
# 75%            1.000000       0.000000      40.715178   170.694603
# max            1.000000       1.000000  129995.778400  1472.522306
#
#        koi_duration     koi_depth       koi_prad     koi_insol  koi_model_snr  \
# count   9564.000000  9.564000e+03    9564.000000  9.564000e+03    9564.000000
# mean       5.621606  2.379134e+04     102.891778  7.745737e+03     259.895001
# std        6.471554  8.066667e+04    3018.662296  1.565099e+05     780.556564
# ...

# %%
numeric_df = copy_exoplanets.select_dtypes(include=['number'])

num_rows = (len(numeric_df.columns) + 1) // 2
num_cols = 2

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(16, 20))

if num_rows == 1:
    axes = [axes]
    
for i, column in enumerate(numeric_df.columns):
    row_index = i // num_cols
    col_index = i % num_cols
    ax = axes[row_index][col_index]
    ax.hist(numeric_df[column], bins=50)  
    ax.set_title(f'Histogram of {column}', fontsize=14)
    ax.set_xlabel(column, fontsize=12)
    ax.set_ylabel('Frequency', fontsize=12)
    ax.grid(True)


plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2. MinMax Scaling

# %% [markdown]
# - Implementing minmax to aid with machine learning models to use (like KNNs, SVMs etc.)
# - Checking that there are no negative values as we will encorporate minmax scaling

# %%
negative_rows = exoplanets[(exoplanets < 0).any(axis=1)]
negative_columns = exoplanets.columns[(exoplanets < 0).any()]

print("Rows containing negative values:")
print(negative_rows)

print("\nColumns containing negative values:")
print(negative_columns)
# Out:
# Rows containing negative values:
# Empty DataFrame
# Columns: [koi_pdisposition, koi_fpflag_nt, koi_period, koi_time0bk, koi_duration, koi_depth, koi_prad, koi_insol, koi_model_snr, koi_slogg, koi_srad]
# Index: []
#
# Columns containing negative values:
# Index([], dtype='object')

# %%
scaler = MinMaxScaler()
scaled_values = scaler.fit_transform(exoplanets.values)
scaled_exoplanets = pd.DataFrame(scaled_values, columns=exoplanets.columns)

print(scaled_exoplanets)
# Out:
#       koi_pdisposition  koi_fpflag_nt  koi_period  koi_time0bk  koi_duration  \
# 0                  1.0            0.0    0.000071     0.036999      0.020980
# 1                  1.0            0.0    0.000417     0.031063      0.032169
# 2                  0.0            0.0    0.000151     0.040928      0.012494
# 3                  0.0            0.0    0.000012     0.036828      0.017001
# 4                  1.0            0.0    0.000018     0.037781      0.011571
# ...                ...            ...         ...          ...           ...
# 9559               0.0            0.0    0.000064     0.008506      0.034328
# 9560               0.0            0.0    0.000002     0.008276      0.022891
# 9561               1.0            0.0    0.000012     0.009235      0.022110
# 9562               0.0            0.0    0.000003     0.008629      0.005871
# 9563               0.0            0.0    0.000035     0.011448      0.021850
#
# ...

# %%
scaled_numeric_df = scaled_exoplanets.select_dtypes(include=['number'])

num_rows = (len(scaled_numeric_df.columns) + 1) // 2
num_cols = 2

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(16, 20))

if num_rows == 1:
    axes = [axes]
    
for i, column in enumerate(scaled_numeric_df.columns):
    row_index = i // num_cols
    col_index = i % num_cols
    ax = axes[row_index][col_index]
    ax.hist(scaled_numeric_df[column], bins=50)  
    ax.set_title(f'Histogram of {column}', fontsize=14)
    ax.set_xlabel(column, fontsize=12)
    ax.set_ylabel('Frequency', fontsize=12)
    ax.grid(True)


plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Log Scaling
# Since a lot of the features are skewed with long tails including: koi_slogg, koi_model_snr, koi_depth, koi_duration, koi_time0bk
# we will deploy log scaling on these features

# %%
columns_to_log_scale = ['koi_slogg', 'koi_model_snr', 'koi_depth', 'koi_duration', 'koi_time0bk'] 
log_scaled_exoplanets = scaled_exoplanets.copy()  # Make a copy to avoid modifying the original minmax scaled
log_scaled_exoplanets += 1e-10 # we cant have zero values so using something insignificantly small
log_scaled_exoplanets[columns_to_log_scale] = log_scaled_exoplanets[columns_to_log_scale].apply(np.log)
log_scaled_exoplanets
# Out:
#       koi_pdisposition  koi_fpflag_nt  koi_period  koi_time0bk  koi_duration  \
# 0         1.000000e+00   1.000000e-10    0.000071    -3.296865     -3.864178
# 1         1.000000e+00   1.000000e-10    0.000417    -3.471725     -3.436757
# 2         1.000000e-10   1.000000e-10    0.000151    -3.195951     -4.382547
# 3         1.000000e-10   1.000000e-10    0.000012    -3.301498     -4.074494
# 4         1.000000e+00   1.000000e-10    0.000018    -3.275959     -4.459219
# ...                ...            ...         ...          ...           ...
# 9559      1.000000e-10   1.000000e-10    0.000064    -4.766982     -3.371797
# 9560      1.000000e-10   1.000000e-10    0.000002    -4.794398     -3.777021
# 9561      1.000000e+00   1.000000e-10    0.000012    -4.684789     -3.811715
# 9562      1.000000e-10   1.000000e-10    0.000003    -4.752680     -5.137808
# 9563      1.000000e-10   1.000000e-10    0.000035    -4.469965     -3.823542
#
# ...

# %%
scaled_numeric_df = log_scaled_exoplanets.select_dtypes(include=['number'])

num_rows = (len(scaled_numeric_df.columns) + 1) // 2
num_cols = 2

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(16, 20))

if num_rows == 1:
    axes = [axes]
    
for i, column in enumerate(scaled_numeric_df.columns):
    row_index = i // num_cols
    col_index = i % num_cols
    ax = axes[row_index][col_index]
    ax.hist(scaled_numeric_df[column], bins=50)  
    ax.set_title(f'Histogram of {column}', fontsize=14)
    ax.set_xlabel(column, fontsize=12)
    ax.set_ylabel('Frequency', fontsize=12)
    ax.grid(True)


plt.tight_layout()
plt.show()

# %% [markdown]
# ## IV. Column Renaming
# Since the column names are hard to interpert the features being displayed, we will rename them to what they indicate

# %%
scaled_exoplanets = scaled_exoplanets.rename(columns={'koi_pdisposition':'Class',
                                                      'koi_fpflag_nt':'Not_Transit-like_False_Positive_Flag', 
                                                      'koi_period':'Orbit_Period', 
                                                      'koi_time0bk':'Transit_Epoch',
                                                      'koi_duration':'Transit_Duration', 
                                                      'koi_depth':'Transit_Depth', 
                                                      'koi_prad':'Planetary_Radius', 
                                                      'koi_insol':'Insolation_Flux', 
                                                      'koi_model_snr':'Transit_Signal-to-Noise',
                                                      'koi_slogg':'Stellar_Surface_Gravity', 
                                                      'koi_srad':'Stellar_Radius'})
scaled_exoplanets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Class                                 9564 non-null   float64
#  1   Not_Transit-like_False_Positive_Flag  9564 non-null   float64
#  2   Orbit_Period                          9564 non-null   float64
#  3   Transit_Epoch                         9564 non-null   float64
#  4   Transit_Duration                      9564 non-null   float64
#  5   Transit_Depth                         9564 non-null   float64
#  6   Planetary_Radius                      9564 non-null   float64
#  7   Insolation_Flux                       9564 non-null   float64
#  8   Transit_Signal-to-Noise               9564 non-null   float64
#  9   Stellar_Surface_Gravity               9564 non-null   float64
# ...

# %%
log_scaled_exoplanets = log_scaled_exoplanets.rename(columns={'koi_pdisposition':'Class',
                                                      'koi_fpflag_nt':'Not_Transit-like_False_Positive_Flag', 
                                                      'koi_period':'Orbit_Period', 
                                                      'koi_time0bk':'Transit_Epoch',
                                                      'koi_duration':'Transit_Duration', 
                                                      'koi_depth':'Transit_Depth', 
                                                      'koi_prad':'Planetary_Radius', 
                                                      'koi_insol':'Insolation_Flux', 
                                                      'koi_model_snr':'Transit_Signal-to-Noise',
                                                      'koi_slogg':'Stellar_Surface_Gravity', 
                                                      'koi_srad':'Stellar_Radius'})
log_scaled_exoplanets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Class                                 9564 non-null   float64
#  1   Not_Transit-like_False_Positive_Flag  9564 non-null   float64
#  2   Orbit_Period                          9564 non-null   float64
#  3   Transit_Epoch                         9564 non-null   float64
#  4   Transit_Duration                      9564 non-null   float64
#  5   Transit_Depth                         9564 non-null   float64
#  6   Planetary_Radius                      9564 non-null   float64
#  7   Insolation_Flux                       9564 non-null   float64
#  8   Transit_Signal-to-Noise               9564 non-null   float64
#  9   Stellar_Surface_Gravity               9564 non-null   float64
# ...

# %%
exoplanets = exoplanets.rename(columns={'koi_pdisposition':'Class',
                                                      'koi_fpflag_nt':'Not_Transit-like_False_Positive_Flag', 
                                                      'koi_period':'Orbit_Period', 
                                                      'koi_time0bk':'Transit_Epoch',
                                                      'koi_duration':'Transit_Duration', 
                                                      'koi_depth':'Transit_Depth', 
                                                      'koi_prad':'Planetary_Radius', 
                                                      'koi_insol':'Insolation_Flux', 
                                                      'koi_model_snr':'Transit_Signal-to-Noise',
                                                      'koi_slogg':'Stellar_Surface_Gravity', 
                                                      'koi_srad':'Stellar_Radius'})
exoplanets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Class                                 9564 non-null   int64
#  1   Not_Transit-like_False_Positive_Flag  9564 non-null   int64
#  2   Orbit_Period                          9564 non-null   float64
#  3   Transit_Epoch                         9564 non-null   float64
#  4   Transit_Duration                      9564 non-null   float64
#  5   Transit_Depth                         9564 non-null   float64
#  6   Planetary_Radius                      9564 non-null   float64
#  7   Insolation_Flux                       9564 non-null   float64
#  8   Transit_Signal-to-Noise               9564 non-null   float64
#  9   Stellar_Surface_Gravity               9564 non-null   float64
# ...

# %%
scaled_exoplanets.Orbit_Period
# Out:
# 0       0.000071
# 1       0.000417
# 2       0.000151
# 3       0.000012
# 4       0.000018
#           ...
# 9559    0.000064
# 9560    0.000002
# 9561    0.000012
# 9562    0.000003
# 9563    0.000035
# Name: Orbit_Period, Length: 9564, dtype: float64

# %%
scaled_exoplanets.to_csv('Cleaned_NasaExoplanetArchive.csv', index = False)

# %%
log_scaled_exoplanets.to_csv('LOG_Cleaned_NasaExoplanetArchive.csv', index = False)

# %% [markdown]
# # Splitting to Train, Test and Validation

# %%
features = scaled_exoplanets.drop(columns = ['Class'])
target = scaled_exoplanets.Class

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=.40)

# %%
for dataset in [y_train, y_test]:
    print(round(len(dataset)/len(target), 2))
# Out:
# 0.6
# 0.4

# %% [markdown]
# # Testing on Different Models

# %%
# Evaluation function

def evaluation(y_true, y_pred):
    
# Print Accuracy, Recall, F1 Score, and Precision metrics.
    print('Evaluation Metrics:')
    print('Accuracy: ' + str(skmetrics.accuracy_score(y_test, y_pred)))
    print('Recall: ' + str(skmetrics.recall_score(y_test, y_pred)))
    print('F1 Score: ' + str(skmetrics.f1_score(y_test, y_pred)))
    print('Precision: ' + str(skmetrics.precision_score(y_test, y_pred)))
    
# Print Confusion Matrix
    print('\nConfusion Matrix:')
    print(' TN,  FP, FN, TP')
    print(confusion_matrix(y_true, y_pred).ravel())
    
# Function Prints best parameters for GridSearchCV
def print_results(results):
    print('Best Parameters: {}\n'.format(results.best_params_))

# %%
# Logistic Regression
lr = LogisticRegression(C=100, max_iter=200, class_weight='balanced')
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
evaluation(y_test, y_pred)
# Out:
# Evaluation Metrics:
# Accuracy: 0.7770517511761631
# Recall: 0.9671125975473801
# F1 Score: 0.8026833217672912
# Precision: 0.686041913799921
#
# Confusion Matrix:
#  TN,  FP, FN, TP
# [1238  794   59 1735]

# %%
n = int(np.sqrt(9563))
n
# Out:
# 97

# %%
# metrics = ['accuracy', 'precision_weighted', 'recall_weighted', 'f1_weighted', 'roc_auc_ovr']
# cross_val = cross_validate(knn, X_train, y_train, cv = 10, scoring = metrics)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 metrics = ['accuracy', 'precision_weighted', 'recall_weighted', 'f1_weighted', 'roc_auc_ovr']
# ----> 2 cross_val = cross_validate(knn, X_train, y_train, cv = 10, scoring = metrics)
#
# NameError: name 'knn' is not defined

# %%
# k_range = list(range(1,n))
# param_grid = {'n_neighbors': k_range} 
# # KNN (EUCLIDEAN)
# knn =  KNeighborsClassifier()

# %%
# find_k = GridSearchCV(knn, param_grid, cv = 10, scoring = 'accuracy')
# find_k.fit(X_train, y_train)

# %%
# best_euc_k = find_k.best_params_['n_neighbors']
# print(best_euc_k)

# %%
# knn_euc = KNeighborsClassifier(n_neighbors = best_euc_k)
# euc_cross_val = cross_validate(knn_euc, X_train, y_train, cv = 10, scoring = metrics)

# %%
# print("\naccuracy:\n")
# print(euc_cross_val['test_accuracy'])
# print("_______________________________________________________________\n")
# print("precision:\n")
# print(euc_cross_val['test_precision_weighted'])
# print("_______________________________________________________________\n")
# print("recall:\n")
# print(euc_cross_val['test_recall_weighted'])
# print("_______________________________________________________________\n")
# print("f1:\n")
# print(euc_cross_val['test_f1_weighted'])
# print("_______________________________________________________________\n")
# print("AUC:\n")
# print(euc_cross_val['test_roc_auc_ovr'])

# %%
# # KNN (MANHATTAN)
# knn_man =  KNeighborsClassifier(metric = 'manhattan')
# find_k_man = GridSearchCV(knn_man, param_grid, cv = 10, scoring = 'accuracy')
# find_k_man.fit(X_train, y_train)

# %%
# best_man_k = find_k_man.best_params_['n_neighbors']
# print(best_man_k)

# %%
# knn_man_new = KNeighborsClassifier(n_neighbors = best_man_k)
# new_man_cross_val = cross_validate(knn_man_new, X_train, y_train, cv = 10, scoring = metrics)

# %%
# print("\naccuracy:\n")
# print(new_man_cross_val['test_accuracy'])
# print("_______________________________________________________________\n")
# print("precision:\n")
# print(new_man_cross_val['test_precision_weighted'])
# print("_______________________________________________________________\n")
# print("recall:\n")
# print(new_man_cross_val['test_recall_weighted'])
# print("_______________________________________________________________\n")
# print("f1:\n")
# print(new_man_cross_val['test_f1_weighted'])
# print("_______________________________________________________________\n")
# print("AUC:\n")
# print(new_man_cross_val['test_roc_auc_ovr'])

# %%
# #Decision Tree
# tree = DecisionTreeClassifier()
# tree.fit(X_train, y_train)
# y_pred = tree.predict(X_test)
# evaluation(y_test, y_pred)

# %%
# #Random Forest
# forest = RandomForestClassifier(n_estimators=100, criterion='gini')
# forest.fit(X_train, y_train)
# y_pred = forest.predict(X_test)
# evaluation(y_test, y_pred)

# %%
# Neural Network (Multi-layer Perceptron)
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(100, ), activation='relu', solver='adam', max_iter=500)
mlp.fit(X_train, y_train)
y_pred = mlp.predict(X_test)
evaluation(y_test, y_pred)
# Out:
# Evaluation Metrics:
# Accuracy: 0.8086774699424987
# Recall: 0.919732441471572
# F1 Score: 0.8184523809523809
# Precision: 0.7372654155495979
#
# Confusion Matrix:
#  TN,  FP, FN, TP
# [1444  588  144 1650]

# %%
# # Support Vector Machine (SVM)
# from sklearn.svm import SVC

# svm = SVC(kernel='rbf', C=1.0, gamma='scale')
# svm.fit(X_train, y_train)
# y_pred = svm.predict(X_test)
# evaluation(y_test, y_pred)

# %%
# # Naive Bayes

# nb = GaussianNB()
# nb.fit(X_train, y_train)
# y_pred = nb.predict(X_test)
# evaluation(y_test, y_pred)

# %%
# xgb = XGBClassifier()
# xgb.fit(X_train, y_train)
# y_pred = xgb.predict(X_test)
# evaluation(y_test, y_pred)

# %%
# # GridSearch Parameters
# parameters = {
#     'n_estimators': [5, 50, 100, 150, 200],
#     'max_depth': list(range(1, 11)),
#     'criterion':['gini','entropy'],
#     'max_features': list(range(1,20)),
#     'oob_score':[False,True],
# }

# %%
# GridSearchCV??

# %%
# grid = GridSearchCV(forest, parameters, cv=5, verbose=1)

# grid.fit(X_train, y_train)
# y_test_grid = grid.predict(X_test)

# # Evaluating model
# evaluation(y_test, y_pred)

# %%
# evaluation(y_test, y_pred)

# %%
# print('done')

# %%
pip install pgmpy

# %% [markdown]
# # Final model choice: Neural Network

# %% [markdown]
# ## I. Optimizing Neural Network

# %% [markdown]
# ### 1. Boosting

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score

# Define parameters for the MLPClassifier
mlp_params = dict(hidden_layer_sizes=(100,), activation='relu', solver='adam', max_iter=200)

# Number of boosting iterations
n_estimators = 50

# Initialize a list to store the individual MLP classifiers
mlp_classifiers = []

# Fit multiple MLP classifiers sequentially to create a boosting effect
for i in range(n_estimators):
    mlp = MLPClassifier(**mlp_params)
    mlp.fit(X_train, y_train)
    mlp_classifiers.append(mlp)

# Make predictions using each MLP classifier and combine results through voting
y_preds = []
for mlp_clf in mlp_classifiers:
    y_preds.append(mlp_clf.predict(X_test))

# Take the majority vote as the final prediction
y_pred_boosted = np.mean(y_preds, axis=0) > 0.5  # Adjust threshold as needed

# Evaluate the boosted model
accuracy = accuracy_score(y_test, y_pred_boosted)
print(f"Boosted Model Accuracy: {accuracy:.4f}")

# %%
print(f"Boosted Model Accuracy: {accuracy:.4f}")
# Out:
# Boosted Model Accuracy: 0.7956

# %% [markdown]
# ### 2. Bagging

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score
# Define the number of base estimators (MLP models) in the ensemble
n_estimators = 10
mlp_models = []

# Train multiple MLP models and store them in a list
for _ in range(n_estimators):
    mlp = MLPClassifier(hidden_layer_sizes=(100,), activation='relu', solver='adam', max_iter=1000)
    mlp.fit(X_train, y_train)
    mlp_models.append(mlp)

# Make predictions with each MLP model and average the predictions
y_preds = np.zeros((len(X_test), n_estimators))
for i, mlp in enumerate(mlp_models):
    y_preds[:, i] = mlp.predict(X_test)

# Average the predictions
y_pred_avg = np.mean(y_preds, axis=1)
y_pred_bagging = np.round(y_pred_avg).astype(int)  # For binary classification, rounding to integers

# Evaluate the performance
accuracy = accuracy_score(y_test, y_pred_bagging)
print(f'Accuracy using bagging: {accuracy:.4f}')
# Out:
# Accuracy using bagging: 0.8131

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
# Define a custom MLP-like model with dropout
model = Sequential([
    Dense(100, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.2),  # Dropout layer with 20% dropout rate
    Dense(1, activation='sigmoid')  # Assuming binary classification
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split=0.1, verbose=0)

# Train the model

# Evaluate the model on the test data
# Evaluate the model on the test data
y_pred_prob = model.predict(X_test)
y_pred_drop = np.round(y_pred_prob).astype(int)  # Convert probabilities to binary predictions

accuracy = accuracy_score(y_test, y_pred)
print(f'MLP with dropout accuracy: {accuracy:.4f}')
evaluation(y_test, y_pred_drop)
# Out:
# 120/120 [==============================] - 0s 2ms/step
# MLP with dropout accuracy: 0.8116
# Evaluation Metrics:
# Accuracy: 0.8478829064296916
# Recall: 0.915273132664437
# F1 Score: 0.8494568028970512
# Precision: 0.7924710424710425
#
# Confusion Matrix:
#  TN,  FP, FN, TP
# [1602  430  152 1642]

# %%
print(f'MLP with dropout accuracy: {accuracy:.4f}')
# Out:
# MLP with dropout accuracy: 0.8547

# %%
val_accuracy = history.history['val_accuracy']
last_val_accuracy = val_accuracy[-1]  # Get the last validation accuracy
print(f'Validation accuracy: {last_val_accuracy:.4f}')
# Out:
# Validation accuracy: 0.8519

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# Define MLPClassifier with batch normalization
mlp_bn = make_pipeline(
    StandardScaler(),
    MLPClassifier(hidden_layer_sizes=(100,), activation='relu', solver='adam', max_iter=200)
)

# Train the model with batch normalization
mlp_bn.fit(X_train, y_train)

# Evaluate the model with batch normalization on the test data
y_pred_bn = mlp_bn.predict(X_test)
accuracy_bn = accuracy_score(y_test, y_pred_bn)

print(f'MLP with batch normalization accuracy: {accuracy_bn:.4f}')

y_pred_train = mlp_bn.predict(X_train)
accuracy_train = accuracy_score(y_train, y_pred_train)

print(f'MLP with batch normalization training accuracy: {accuracy_train:.4f}')
evaluation(y_test, y_pred_bn)
# Out:
# MLP with batch normalization accuracy: 0.8594
# MLP with batch normalization training accuracy: 0.8613
# Evaluation Metrics:
# Accuracy: 0.8593831677992682
# Recall: 0.8907469342251951
# F1 Score: 0.8559185859667916
# Precision: 0.8237113402061855
#
# Confusion Matrix:
#  TN,  FP, FN, TP
# [1690  342  196 1598]
# /Users/layla/Documents/ImageClassification/imageclassification/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define a custom MLP-like model with dropout and the same normalization as MLPClassifier
model = Sequential([
    Dense(100, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    Dropout(0.2),  # Dropout layer with 20% dropout rate
    Dense(100, activation='relu'),
    Dropout(0.2),  # Dropout layer with 20% dropout rate
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train_scaled, y_train, epochs=500, batch_size=32, validation_split=0.1, verbose=0)

# Evaluate the model on the test data
y_pred_prob = model.predict(X_test_scaled)
y_pred_combined = np.round(y_pred_prob).astype(int)
accuracy = accuracy_score(y_test, y_pred)
print(f'Combined model accuracy: {accuracy:.4f}')
evaluation(y_test, y_pred_combined)
# Out:
# 120/120 [==============================] - 1s 4ms/step
# Combined model accuracy: 0.8087
# Evaluation Metrics:
# Accuracy: 0.876633559853633
# Recall: 0.919732441471572
# F1 Score: 0.8748674443266172
# Precision: 0.8341759352881699
#
# Confusion Matrix:
#  TN,  FP, FN, TP
# [1704  328  144 1650]

# %%
# import pickle
# from tensorflow.keras.models import save_model

# # Train your model
# # Assuming 'model' is already trained as per your previous code

# # Save the model using Keras's save_model function
# model.save("Exoplanet_Model.h5")

# # Now, let's save the StandardScaler object using pickle
# with open("scaler.pkl", "wb") as scaler_file:
#     pickle.dump(scaler, scaler_file)
